# %% [markdown]
# <a href="https://colab.research.google.com/github/AliShujjat/DropOutRatesInPakistan/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Retrieving the data from Google Drive
from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/drive/My Drive/Edu/Edu.csv" "Edu.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Edu.csv')

# %%
df.head()
# Out:
#    Year of Survey Type of place of residence  ...  GS021z       _merge
# 0            2018                      Rural  ...     0.0  matched (3)
# 1            2018                      Rural  ...     0.0  matched (3)
# 2            2018                      Rural  ...     0.0  matched (3)
# 3            2018                      Rural  ...     0.0  matched (3)
# 4            2018                      Rural  ...     0.0  matched (3)
#
# [5 rows x 205 columns]

# %%
df.rename(columns={'Gender ':'Gender'},inplace=True)

# %%
df.select_dtypes("object")
labels = ['Type of place of residence','Gender','Edu status','Reasons for dropout','If Drop-out, studied up-to which\nclass','Current Class-Grade of Child','Currently Enrolled: Institution type','Enrolled child currently taking any paid tution','Windex','Type of household','mergeone','Name of Province/Territory','Name of the District','Local Language of the Village','mergetwo','Mother education','PR005','Father education status','If gone, what was grade last completed by father?','mergethree','GS001a','GS003a','GS005','GS012d','_merge']

# %%
#Label Encoding
for i in labels:
  df[i]= df[i].astype('category')
  label = dict(enumerate(df[i].cat.categories))
  df[[i]] = df[[i]].apply(lambda x: x.cat.codes)

# %%
#Save labelled data
df.to_csv('Edu1.csv')

# %% [markdown]
# #Feature Selection#

# %%
df = pd.read_csv('Edu1.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  Year of Survey  ...  GS021z  _merge
# 0           0            2018  ...     0.0       1
# 1           1            2018  ...     0.0       1
# 2           2            2018  ...     0.0       1
# 3           3            2018  ...     0.0       1
# 4           4            2018  ...     0.0       1
# 5           5            2018  ...     0.0       1
# 6           6            2018  ...     0.0       1
# 7           7            2018  ...     0.0       1
# 8           8            2018  ...     0.0       1
# 9           9            2018  ...     0.0       1
#
# [10 rows x 206 columns]

# %%
df.replace(-1,50,inplace=True)
df.replace(np.nan,50,inplace=True)

# %%
df = df.abs()

# %%
df.iloc[:,9]
# Out:
# 0         1.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
#          ...
# 260181    3.0
# 260182    1.0
# 260183    1.0
# 260184    1.0
# 260185    3.0
# Name: Education Status of Child, Length: 260186, dtype: float64

# %% [markdown]
# Using Select K-best

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
 
#Input attributes
X= df.iloc[:,:]
 
#outout attribute
Y = df.iloc[:,9]

# %%
#apply SelectKBest class to extract top 4 best features
bestfeatures = SelectKBest(score_func=chi2, k=50)
fitted = bestfeatures.fit(X,Y)
reducedFeatures = fitted.transform(X)
print(X.shape)
print(reducedFeatures.shape)
# Out:
# (260186, 206)
# (260186, 50)

# %%
dfscores = pd.DataFrame(fitted.scores_)
dfcolumns = pd.DataFrame(X.columns)
 
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] #naming the dataframe columns
 
print(featureScores.nlargest(50,'Score')) #print 10 best features
# Out:
#                                                  Specs         Score
# 144                                              GS017  2.694561e+08
# 146                                             GS018a  2.573546e+08
# 151                                             GS018e  1.310804e+08
# 0                                           Unnamed: 0  9.811529e+07
# 152                                             GS018f  7.467815e+07
# 176                                             GS020a  7.352551e+07
# 177                                            GS020b1  3.442314e+07
# 148                                            GS018b2  2.630151e+07
# 182                                             GS020f  2.150243e+07
# 147                                            GS018b1  2.107011e+07
# 181                                             GS020e  2.090006e+07
# 16                Currently Enrolled: Institution type  8.609198e+06
# 15               Currentlly enrolled: Institution Type  8.146379e+06
# 178                                            GS020b2  4.507197e+06
# 85                      Unique ID of government school  4.051329e+06
# 14                        Current Class-Grade of Child  4.008529e+06
# 10                                          Edu status  3.714055e+06
# 150                                             GS018d  3.532817e+06
# 24                                                C011  3.081504e+06
# 21                                                C010  2.503094e+06
# 38                                              WSCORE  2.321149e+06
# 25                                   Arithmetic Levels  2.192890e+06
# 18                                               C008a  1.935260e+06
# 20                                               C008b  1.778749e+06
# 29                                                C013  1.603913e+06
# 40                                              Windex  1.420850e+06
# 153                                             GS018g  9.239820e+05
# 9                            Education Status of Child  9.154433e+05
# 39                             WINDEX/Economic Profile  8.521563e+05
# 11                                 Reasons for Dropout  4.221813e+05
# 12                                 Reasons for dropout  4.191661e+05
# 17                                                C007  4.170456e+05
# 94                                              GS007E  3.861570e+05
# 95                                              GS007P  3.781689e+05
# 6                                         Age of Child  2.798464e+05
# 75   Total number of surviving children (LESS THAN ...  2.741498e+05
# 183                                             GS020g  2.375501e+05
# 13             If Drop-out, studied up-to which\nclass  2.342313e+05
# 179                                             GS020c  1.820027e+05
# 7                                      Gender of Child  1.579969e+05
# 28                                               C012c  1.450497e+05
# 27                                               C012b  1.354414e+05
# 77                              PR004/Mother Education  1.337956e+05
# 81                     Has father ever gone to school?  1.251086e+05
# 149                                             GS018c  1.141375e+05
# 26                                               C012a  1.042545e+05
# 175                                              GS020  9.881989e+04
# 145                                              GS018  9.876820e+04
# 91                                              GS003Y  9.249964e+04
# 5                                                  DID  4.512488e+04

# %% [markdown]
# FEATURE SELECTION AND PREPROCESSING PT 2

# %%
df = pd.read_csv('Edu.csv')
df.rename(columns={'Gender ':'Gender'},inplace=True)

# %%
df = df.replace(np.nan, df.mode(dropna = True).iloc[0])

labels = ['Type of place of residence','Gender','Edu status','Reasons for dropout','If Drop-out, studied up-to which\nclass','Current Class-Grade of Child','Currently Enrolled: Institution type','Enrolled child currently taking any paid tution','Windex','Type of household','mergeone','Name of Province/Territory','Name of the District','Local Language of the Village','mergetwo','Mother education','PR005','Father education status','If gone, what was grade last completed by father?','mergethree','GS001a','GS003a','GS005','GS012d','_merge']
for i in labels:
  df[i]= df[i].astype('category')
  label = dict(enumerate(df[i].cat.categories))
  df[[i]] = df[[i]].apply(lambda x: x.cat.codes)

# %%
df.replace(-1,1,inplace=True)
cols = df.columns[df.nunique() <= 1]
print(cols)
print(df.isnull().sum().sum())
for i in range(len(cols)):
    df.drop([cols[i]], axis=1, inplace = True)
    
print(df.columns[df.nunique() <= 1])
print(df.isnull().sum().sum())
# Out:
# Index(['Year of Survey', 'Type of place of residence',
#        'Type of Place of Residence', 'C013a', 'C013b', 'C016', 'C017', 'SYEAR',
#        'HPSPA', 'mergeone', 'Area', 'mergetwo', 'mergethree', 'GS018',
#        'GS020'],
#       dtype='object')
# 780558
# Index([], dtype='object')
# 0

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import f_classif
 
#Input attributes
X= df.iloc[:,:]
 
#outout attribute
Y = df.iloc[:,7]

# %%
dfscores = pd.DataFrame(fitted.scores_)
dfcolumns = pd.DataFrame(X.columns)
 
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] #naming the dataframe columns
 
print(featureScores.nlargest(50,'Score')) #print 10 best features
# Out:
#                                                Specs         Score
# 144                                           GS019e  2.694561e+08
# 146                                           GS019g  2.573546e+08
# 151                                           GS019m  1.310804e+08
# 0                                                RID  9.811529e+07
# 152                                           GS019n  7.467815e+07
# 176                                           GS021h  7.352551e+07
# 177                                           GS021i  3.442314e+07
# 148                                           GS019i  2.630151e+07
# 182                                           GS021p  2.150243e+07
# 147                                           GS019h  2.107011e+07
# 181                                           GS021n  2.090006e+07
# 16                                             C008b  8.609198e+06
# 15   Enrolled child currently taking any paid tution  8.146379e+06
# 178                                           GS021j  4.507197e+06
# 85                                            GS009a  4.051329e+06
# 14                                             C008a  4.008529e+06
# 10                      Current Class-Grade of Child  3.714055e+06
# 150                                           GS019k  3.532817e+06
# 24                                             C012c  3.081504e+06
# 21                                 Arithmetic Levels  2.503094e+06
# 38                                              H003  2.321149e+06
# 25                                              C013  2.192890e+06
# 18                                             C010a  1.935260e+06
# 20                                              C011  1.778749e+06
# 29                                              C019  1.603913e+06
# 40                                              H005  1.420850e+06
# 153                                           GS019p  9.239820e+05
# 9            If Drop-out, studied up-to which\nclass  9.154433e+05
# 39                                              H004  8.521563e+05
# 11             Currentlly enrolled: Institution Type  4.221813e+05
# 12              Currently Enrolled: Institution type  4.191661e+05
# 17                                              C010  4.170456e+05
# 94                                            GS010c  3.861570e+05
# 95                                            GS010d  3.781689e+05
# 6                                         Edu status  2.798464e+05
# 75                              GS003/English Medium  2.741498e+05
# 183                                           GS021q  2.375501e+05
# 13                                              C007  2.342313e+05
# 179                                           GS021k  1.820027e+05
# 7                                Reasons for Dropout  1.579969e+05
# 28                                              C018  1.450497e+05
# 27                                              C015  1.354414e+05
# 77                                            GS003Y  1.337956e+05
# 81                                            GS007P  1.251086e+05
# 149                                           GS019j  1.141375e+05
# 26                                              C014  1.042545e+05
# 175                                           GS021g  9.881989e+04
# 145                                           GS019f  9.876820e+04
# 91                                            GS009z  9.249964e+04
# 5                          Education Status of Child  4.512488e+04

# %% [markdown]
# PCA

# %%
import numpy
from pandas import read_csv
from sklearn.decomposition import PCA
# load data

#Input attributes
X= df.iloc[:,:]
 
#outout attribute
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] #naming the dataframe columns
 
print(featureScores.nlargest(30,'Score')) #print 10 best features
#print(model.feature_importances_)
# Out:
#                                                 Specs     Score
# 9             If Drop-out, studied up-to which\nclass  0.153789
# 5                           Education Status of Child  0.120888
# 6                                          Edu status  0.096280
# 7                                 Reasons for Dropout  0.071550
# 2                                        Age of Child  0.047211
# 8                                 Reasons for dropout  0.027974
# 25                                               C013  0.011933
# 61                    Age of mother (completed years)  0.011692
# 21                                  Arithmetic Levels  0.011584
# 33                                           HCOUNTER  0.011338
# 67                    Age of father (completed years)  0.011323
# 17                                               C010  0.010696
# 62  Total number of surviving children (LESS THAN ...  0.009966
# 30                                             WSCORE  0.008446
# 3                                     Gender of Child  0.007679
# 34                                              H001M  0.007633
# 4                                              Gender  0.007564
# 1                                                 DID  0.007511
# 35                                              H001F  0.007478
# 51                               Name of the District  0.006920
# 71                     Unique ID of government school  0.006852
# 80                                             GS007E  0.006129
# 81                                             GS007P  0.006121
# 77                                             GS003Y  0.006092
# 52                      Local Language of the Village  0.006064
# 22                                              C012a  0.006041
# 45                                               H010  0.005914
# 31                            WINDEX/Economic Profile  0.005905
# 32                                             Windex  0.005864
# 59                                               V007  0.005392

# %%
scored = featureScores.nlargest(35,'Score')

# %%
Row_list =[] 
  
for index, rows in scored.iterrows(): 
    my_list = rows.Specs 
    Row_list.append(my_list) 
  

print(Row_list[:30])
# Out:
# ['If Drop-out, studied up-to which\nclass', 'Education Status of Child', 'Edu status', 'Reasons for Dropout', 'Age of Child', 'Reasons for dropout', 'C013', 'Age of mother (completed years)', 'Arithmetic Levels', 'HCOUNTER', 'Age of father (completed years)', 'C010', 'Total number of surviving children (LESS THAN 17) of mother', 'WSCORE', 'Gender of Child', 'H001M', 'Gender', 'DID', 'H001F', 'Name of the District', 'Unique ID of government school', 'GS007E', 'GS007P', 'GS003Y', 'Local Language of the Village', 'C012a', 'H010', 'WINDEX/Economic Profile', 'Windex', 'V007']

# %%
filtered = df[['If Drop-out, studied up-to which\nclass', 'Education Status of Child', 'Edu status', 'Reasons for Dropout', 'Age of Child', 'Reasons for dropout', 'C013', 'Age of father (completed years)', 'C010', 'HCOUNTER', 'Age of mother (completed years)', 'Arithmetic Levels', 'Total number of surviving children (LESS THAN 17) of mother', 'WSCORE', 'H001M', 'H001F', 'Gender of Child', 'DID', 'Gender', 'C012a', 'Unique ID of government school', 'Name of the District', 'GS007P', 'GS003Y', 'Local Language of the Village', 'GS007E', 'H010', 'WINDEX/Economic Profile', 'Windex', 'V007']]

# %%
filtered.head()
# Out:
#    If Drop-out, studied up-to which\nclass  ...  V007
# 0                                       19  ...   2.0
# 1                                       19  ...   2.0
# 2                                       19  ...   2.0
# 3                                       19  ...   2.0
# 4                                       19  ...   2.0
#
# [5 rows x 30 columns]

# %%
filtered.to_csv('Edu3.csv')
